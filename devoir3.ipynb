# %% [markdown]
# # Devoir 3

# %% [markdown]
# J'importe les modules nécessaires:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %% [markdown]
# Je change les options d'affichage

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %% [markdown]
# Je lis le csv que j'ai préalablement importé:

# %%
ai = pd.read_csv("ati.csv")

# %% [markdown]
# Je l'affiche, question de voir ce qu'il contient:

# %%
ai
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %%
ai.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %% [markdown]
# Je regarde combien de demandes ont été déposées en tout à chaque année:

# %%
ai.year.value_counts()
# Out:
# 2016    15016
# 2015    12630
# 2017     1115
# Name: year, dtype: int64

# %% [markdown]
# Je fais un décompte par service gouvernemental pour voir qui a reçu le plus de de demandes:

# %%
ai.owner_org_title.value_counts()
# Out:
# National Defence | Défense nationale                                                                                                                             2605
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1650
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1541
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1323
# Health Canada | Santé Canada                                                                                                                                     1164
# ...

# %% [markdown]
# On voit que la Défense nationale est celui qui a reçu le plus de demande (2605).

# %% [markdown]
# J'en profite pour faire un petit graphique illustrant le nombre de demandes par service gouvernemental:

# %%
ai.owner_org_title.value_counts().plot(kind="pie", title="Demandes par service gouvernemental")

# %% [markdown]
# Je cherche alors combien de demandes en tout ont été refusés:

# %%
ai.disposition.str.contains("Tous exclus").value_counts()
# Out:
# False    28646
# True        94
# Name: disposition, dtype: int64

# %% [markdown]
# On voit que 94 requêtes ont été entièrement refusées.
